# %%
from numpy import *
from matplotlib.pyplot import *

# %%
def f(x):
    return sin(x)

# %%
x = linspace(0, 4*pi, 100)
y = f(x) + random.normal(0, 0.1, len(x))
dx = x[1] - x[0]

# %%
import pandas as pd
df = pd.DataFrame()
df['x'] = x
df['y'] = y
df.to_csv('data.csv', index=None)

# %%
scatter(x, y, s=20)
savefig('fig.svg', format='svg', dpi=600)

# %%
# 中心差分法による数値微分
def cdiff(x):
    d = append(x[1:], nan)
    d_ = append(nan, x[:-1])
    return (d - d_) / 2

# %%
scatter(x, y, s=1)
scatter(x, cdiff(y)/dx, s=1, c='red')

# %%
scatter(x, cdiff(y)/dx, s=1, c='red')
scatter(x[1:], diff(y)/dx, s=1, c='green')
